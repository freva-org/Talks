# %% [markdown]
# <style>
# h1 {
#     font-size: 1.8em !important;
# }
#
# img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
#     max-height: 65vh;
# }
#
# .reveal p {
#     color: black;
# }
#
# .reveal pre {
#     color: black;
# }
#
# div.hl-ipython3 pre {
#     color: black;
# }
#
# .reveal li {
#     color: black;
# }
#
# .reveal div.highlight pre {
#     color: black;
# }
#
# div.prompt, div.jp-InputPrompt, div.jp-InputArea-prompt, div.jp-OutputPrompt, div.jp-OutputArea-prompt {
#     display: none !important;
# }
#
# .reveal .slides {
#     max-width: 95% !important;
#     width: 65% !important;
#     margin: auto !important;
#     padding: 0 2em; /* optional: horizontal padding */
#     display: flex;
#     flex-direction: column; /* Stack slides vertically */
#     align-items: flex-start; /* Align items to the top */
# }
#
# /* Center and constrain individual slide content */
# .reveal .slides section {
#     max-width: 1000px;  /* or adjust as needed */
#     margin: 0 auto !important;
#     display: flex; /* Ensure flexbox is applied */
#     flex-direction: column; /* Stack items vertically */
#     align-items: flex-start; /* Align items to the top */
#     min-height: 100vh; /* Ensure sections take full height */
# }
#
# .reveal .slides section p {
#     margin: 0; /* Reset margins for paragraphs */
#     text-align: left; /* Align text to the left */
# }
#
# .reveal img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
# .reveal {
#   /* Reveal.js uses flex on the root to center slides
#      — we switch that to top-align instead */
#   align-items: flex-start !important;
#   margin: 0;
#    position: absolute;
#     top: 0;
#     left: 0;
# }
#
# /* 2) Ensure the slides wrapper also top-aligns its direct children */
# .reveal .slides {
#   align-items: flex-start !important;
#   margin: 0;
#    position: absolute;
#     top: 0;
#     left: 0;
# }
#
# /* 3) Zero out any auto top-margins on the current slide */
# .reveal .slides section.present {
#   margin-top: 0 !important;
# }
# </style>
